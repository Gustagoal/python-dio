# %%
import pandas as pd
import numpy as np

df1 = pd.read_excel(r"C:\Users\Gustavo Castro\Desktop\python-dio\etl\arquivos\categorias.xlsx")
df2 = pd.read_excel(r"C:\Users\Gustavo Castro\Desktop\python-dio\etl\arquivos\produtos.xlsx")

 # Tail() Verifica as ultimas linhas da base de dados 
# display(list(df2["Marca_Produto"].unique()))

df2["Promoção"] = np.where(df2["Marca_Produto"] == "SAMSUNG","Em promoção","Na Black Friday")
display(df2)
# Out:
#     ID_Produto                           Nome_Produto  ID_Categoria  \
# 0            1        Monitor LED 19,5'' Full HD HDMI             1
# 1            2          Monitor Curvo 24'' 144Hz HDMI             1
# 2            3                   Webcam Full HD 1080p             1
# 3            4   Kit Teclado + Mouse sem fio Wireless             2
# 4            5     Kit Teclado + Mouse Slim Bluetooth             2
# 5            6  Cadeira Gamer reclinável Azul/Laranja             3
# 6            7        Cadeira Gamer PC Racer Vermelha             3
# 7            8               Headphone Bluetooth 2000             4
# 8            9              Fone de Ouvido Tune T5000             4
# 9           10           Microfone Condensador MC1000             5
# 10          11        Microfone Condensador com Tripé             5
# 11          12  Microfone de mesa com fio condensador             5
# 12          13      Notebook LC2100 Intel Core i5 8GB             6
# ...
