# %%
import pandas as pd
import numpy as np

df1 = pd.read_excel(r"C:\Users\Gustavo Castro\Desktop\python-dio\etl\arquivos\categorias.xlsx")
df2 = pd.read_excel(r"C:\Users\Gustavo Castro\Desktop\python-dio\etl\arquivos\produtos.xlsx")

 # Tail() Verifica as ultimas linhas da base de dados 
display(df2["Nome_Produto"])
df1_analise = df2["Nome_Produto"].str.upper()
display(df1_analise)
# Out:
# 0           Monitor LED 19,5'' Full HD HDMI
# 1             Monitor Curvo 24'' 144Hz HDMI
# 2                      Webcam Full HD 1080p
# 3      Kit Teclado + Mouse sem fio Wireless
# 4        Kit Teclado + Mouse Slim Bluetooth
# 5     Cadeira Gamer reclinável Azul/Laranja
# 6           Cadeira Gamer PC Racer Vermelha
# 7                  Headphone Bluetooth 2000
# 8                 Fone de Ouvido Tune T5000
# 9              Microfone Condensador MC1000
# 10          Microfone Condensador com Tripé
# 11    Microfone de mesa com fio condensador
# 12        Notebook LC2100 Intel Core i5 8GB
# 13            Notebook Inspiron 15 5000 4GB
# 14                 Notebook IdeaPad RF32000
# 15                  Notebook Motion Ultra 2
# Name: Nome_Produto, dtype: object
# 0           MONITOR LED 19,5'' FULL HD HDMI
# 1             MONITOR CURVO 24'' 144HZ HDMI
# 2                      WEBCAM FULL HD 1080P
# 3      KIT TECLADO + MOUSE SEM FIO WIRELESS
# 4        KIT TECLADO + MOUSE SLIM BLUETOOTH
# 5     CADEIRA GAMER RECLINÁVEL AZUL/LARANJA
# 6           CADEIRA GAMER PC RACER VERMELHA
# 7                  HEADPHONE BLUETOOTH 2000
# 8                 FONE DE OUVIDO TUNE T5000
# 9              MICROFONE CONDENSADOR MC1000
# 10          MICROFONE CONDENSADOR COM TRIPÉ
# 11    MICROFONE DE MESA COM FIO CONDENSADOR
# 12        NOTEBOOK LC2100 INTEL CORE I5 8GB
# 13            NOTEBOOK INSPIRON 15 5000 4GB
# 14                 NOTEBOOK IDEAPAD RF32000
# 15                  NOTEBOOK MOTION ULTRA 2
# Name: Nome_Produto, dtype: object
