# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustagoal/python-dio/blob/main/arquivo_ordenado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

try:
  df.to_csv("titanic.csv")
  print("Arquivo salvo com sucesso !!")
except Exception as e:
  print("Erro ao tentar salvar")
# Out:
# Arquivo salvo com sucesso !!

# %%
ordenado = df["Name"].sort_values()
display(ordenado.head())
display(df["Name"].head())
